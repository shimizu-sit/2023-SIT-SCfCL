# %% [markdown]
# # コンピュータリテラシ発展 第8回 課題
#
# 今回の課題は**フォルダやファイルの操作**の問題が3問です．

# %% [markdown]
# ## 注意事項
#
# このノートブックは，授業中に作成したフォルダを利用してください．
#
# `/content/drive/MyDrive/???`
#
# 課題内で「作業場所」という言葉が出てきます．それは授業中に作成したフォルダのことです．

# %% [markdown]
# ## ライブラリをインポート
# 各自必要と思うライブラリやメソッドなどをインポートしてください．

# %%
import os, glob, pprint, shutil

# %% [markdown]
# ## 問題1：ファイルの作成
#
# 作業場所に「Prac08-1.txt」という名前の新しいファイルを作成し，「コンピュータリテラシ発展 課題08-1」と書き込んでください．

# %%
with open('/content/drive/MyDrive/SIT_2023/SCfCL/Prac08-1.txt', 'x') as f:
  f.write('コンピュータリテラシ発展 課題08-1')

# %% [markdown]
# ## 問題2：フォルダの作成と移動
#
# 作業場所に「Prac08-1」という名前の新しいフォルダを作成してください．
# 問題1で作成したファイルをこのフォルダに移動してください．

# %%
os.makedirs('/content/drive/MyDrive/SIT_2023/SCfCL/Prac08-1', exist_ok=True)
shutil.move('/content/drive/MyDrive/SIT_2023/SCfCL/Prac08-1.txt', '/content/drive/MyDrive/SIT_2023/SCfCL/Prac08-1/')
# Out:
# '/content/drive/MyDrive/SIT_2023/SCfCL/Prac08-1/Prac08-1.txt'

# %% [markdown]
# ## 問題3：フォルダのコピー
#
# 問題2で作成したフォルダをコピーして「Prac08-1-copy」としてください．

# %%
shutil.copytree('/content/drive/MyDrive/SIT_2023/SCfCL/Prac08-1', '/content/drive/MyDrive/SIT_2023/SCfCL/Prac08-1-copy')
# Out:
# '/content/drive/MyDrive/SIT_2023/SCfCL/Prac08-1-copy'

# %% [markdown]
# ## 問題4：ファイル名の変更
#
# 問題3でコピーしたフォルダ内にあるファイル名を「Prac08-1-copy.txt」としてください．

# %%
os.rename('/content/drive/MyDrive/SIT_2023/SCfCL/Prac08-1-copy/Prac08-1.txt', '/content/drive/MyDrive/SIT_2023/SCfCL/Prac08-1-copy/Prac08-1-copy.txt')
